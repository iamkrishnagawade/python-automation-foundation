# %% [markdown]
# # Python Classes & Objects - Complete, Simple & Practical Guide

# %% [markdown]
# ### What is a Class?

# %% [markdown]
# A class is a blueprint or template used to create objects.<br>
# <br>
# Think of a class like a form used to create many employees:
# <br>
# - Every employees has name, id, department ---> ***attribute***
# - Every employees can clock in, work, take leave ---> ***behaviors/methods***

# %%
# this define a class, but not useful yet
class Employee:
    pass

# %% [markdown]
# ### What is an Object?

# %% [markdown]
# A object is an instance of a class. <br>
# <br>
# If a class is a template then object is the real thing based on that template.

# %%
emp1 = Employee()
emp2 = Employee()

# each object is separate memory.

# %% [markdown]
# ### Adding attributes (Variables inside a Class)

# %% [markdown]
# We usually initialize attribute using ***constructor***
#
# ``` Python
# __init__()
# ```

# %%
class Employee:
    def __init__(self, name, id):
        self.name = name
        self.id = id

# %% [markdown]
# #### Creating objects

# %%
emp1 = Employee("Krishna", 101)
emp2 = Employee("Shridhar", 102)

# %% [markdown]
# #### Understanding self

# %% [markdown]
# self refer to the current object

# %%
class Test:
    def show(self):
        print("Object is: ", self) 

# self allow each object to maintain its own data.

# %% [markdown]
# ### Adding Methods (Functions inside a Class)

# %%
class Employee:
    def __init__(self, name, id):
        self.name = name
        self.id = id

    def display(self):
        print(f"Name: {self.name}, ID: {self.id}")

# %%
# calling method

emp1 = Employee("Krishna", 101)
emp1.display()

# method always takes ***self*** as a first parameter.
# Out:
# Name: Krishna, ID: 101

# %% [markdown]
# ### Types of Methods

# %% [markdown]
# There are three type of methods
# 1. Instance methods
# 2. Class methods
# 3. Static methods

# %% [markdown]
# #### Instances methods

# %%
# affect object level data
def update_name(self, new_name):
    self.name = new_name

# %% [markdown]
# #### Class methods (@classmethod)

# %%
# work with class-level data

class Employee:
    company = "The Oora Studio"

    @classmethod
    def change_company(cls, new_compnay):
        cls.company = new_company

# %% [markdown]
# #### Static methods (@staticmethod)

# %%
# Utility function inside a class

@staticmethod
def is_validid(emp_id):
    return emp_id > 0

# %% [markdown]
# ### Class Variables vs Instance Variables

# %%
class Employee:
    # class var
    company = "Oora" # define outside __init__ and belongs to class level 
    
    def __init__(self, name):
        # instance var
        self.name = name # define inside __init__ and belongs to each object

# %% [markdown]
# ### Practice QA Example

# %% [markdown]
# Automation framework always use classes.

# %% [markdown]
# ***Example: Page-Object Model***

# %%
class LoginPage:
    def __init__(self, page):
        self.page = page
        self.username = page.locator("#username")
        self.password = page.locator("#password")
        self.login_btn = page.locator("#login-btn")

    def login(self, user, pwd):
        self.username.fill(user)
        self.password.fill(pwd)
        self.login_btn.click()

# This is how classes are used in Playwright/Selenium to structure automation code.

# %% [markdown]
# ### Magic Methods — Special Python behaviours

# %% [markdown]
# ```__init__``` -> constructor <br>
# ```__str__``` -> print object nicely <br>
# ```__len__```, ```__add__``` -> used in operator overloading

# %%
class Employee:
    def __str__(self):
        return f"Employee({self.name})"

# %% [markdown]
# ### Encapsulation
# Using private variable

# %%
class Account:
    def __init__(self, balance):
        self.__balance = balance # private

    def get_balance(self):
        return self.__balance

# %% [markdown]
# ### Polymorphism
# Same method name -> different implementation

# %%
class Tester:
    def work(self):
        print("Testing")

class Developer:
      def work(self):
          print("Coding")

# %% [markdown]
# ### COMPLETE Example (Simple & Realistic)

# %%
class Employee:
    company = "Oora"

    def __init__(self, name, role, salary):
        self.name = name
        self.role = role
        self.salary = salary

    def display(self):
        print(f"{self.name} | {self.role} | {self.salary}")

    @classmethod
    def change_company(cls, new_compnay):
        cls.compnay = new_compnay
        print(f"New Company name: {new_compnay}")

    @staticmethod
    def is_valid_salary(sal):
        return sal > 0

# %%
emp1 = Employee("Krishna", "QA", 100)
emp1.display()
emp1.change_company("The Oora Studio")
emp1.is_valid_salary(100)
# Out:
# Krishna | QA | 100
# New Company name: The Oora Studio
# True

# %% [markdown]
# ### INTERVIEW QUESTIONS
#
# 🔥 Basic
#
# - What is a class in Python?
# - What is an object?
# - What is self?What is the purpose of __init__()?
# - What is the difference between a class variable and an instance variable?
#
# 🔥 Intermediate
#
# - Explain types of methods: instance, class, static.
# - How does inheritance work in Python?
# - What is polymorphism?
# - How do you make a variable private in Python?
# - Can Python have multiple inheritance?
#
# 🔥 Advanced (for QA + Automation interviews)
#
# - How are classes used in Page Object Model?
# - Why do we use classes in automation frameworks?
# - Explain the role of constructors in Selenium/Test Automation?
# - What is the difference between composition and inheritance?
# - Explain method overriding with an example.
